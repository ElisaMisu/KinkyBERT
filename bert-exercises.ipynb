# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os

os.environ['TOKENIZERS_PARALLELISM'] = 'false'

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /opt/conda/lib/python3.10/site-packages (0.16.2)
# Requirement already satisfied: numpy>=1.20.0 in /opt/conda/lib/python3.10/site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /opt/conda/lib/python3.10/site-packages (from bertopic) (0.8.36)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from bertopic) (0.5.6)
# Requirement already satisfied: pandas>=1.1.5 in /opt/conda/lib/python3.10/site-packages (from bertopic) (2.1.4)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/conda/lib/python3.10/site-packages (from bertopic) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/conda/lib/python3.10/site-packages (from bertopic) (4.66.1)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from bertopic) (3.0.0)
# Requirement already satisfied: plotly>=4.7.0 in /opt/conda/lib/python3.10/site-packages (from bertopic) (5.18.0)
# Requirement already satisfied: cython<3,>=0.27 in /opt/conda/lib/python3.10/site-packages (from hdbscan>=0.8.29->bertopic) (0.29.37)
# Requirement already satisfied: scipy>=1.0 in /opt/conda/lib/python3.10/site-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /opt/conda/lib/python3.10/site-packages (from hdbscan>=0.8.29->bertopic) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->bertopic) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.5->bertopic) (2023.4)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from plotly>=4.7.0->bertopic) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from plotly>=4.7.0->bertopic) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.39.3)
# Requirement already satisfied: torch>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.1.2)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.22.2)
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from sentence-transformers>=0.4.1->bertopic) (9.5.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/conda/lib/python3.10/site-packages (from umap-learn>=0.5.0->bertopic) (0.58.1)
# Requirement already satisfied: pynndescent>=0.5 in /opt/conda/lib/python3.10/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.12)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (4.9.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /opt/conda/lib/python3.10/site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.41.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->plotly>=4.7.0->bertopic) (3.1.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.4.1->bertopic) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
# import bertopic
# import pandas as pd 
# import numpy as np
# from bertopic import BERTopic
# from IPython.display import clear_output

# %% [markdown]
# download and install BERT

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups


docs = fetch_20newsgroups(subset='all') ['data']
topic_model = BERTopic()
topics, probabilities = topic_model.fit_transform(docs)

def __init__ (self, 
             language:str = "english",
             top_n_words: int=10,
             n_gram_range: Tuple[int, int]=(1,1),
             min_topic_size:int=10,
             nr_topics: Union(int,str)=None,
              low_memory: bool = False
            , 
              
             )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 7
#       5 docs = fetch_20newsgroups(subset='all') ['data']
#       6 topic_model = BERTopic()
# ----> 7 topics, probabilities = topic_model.fit_transform(docs)
#
# File /opt/conda/lib/python3.10/site-packages/bertopic/_bertopic.py:387, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     384     logger.info("Embedding - Transforming documents to embeddings.")
#     385     self.embedding_model = select_backend(self.embedding_model,
#     386                                           language=self.language)
# --> 387     embeddings = self._extract_embeddings(documents.Document.values.tolist(),
#     388                                           images=images,
#     389                                           method="document",
#     390                                           verbose=self.verbose)
#     391     logger.info("Embedding - Completed \u2713")
#     392 else:
#
# File /opt/conda/lib/python3.10/site-packages/bertopic/_bertopic.py:3410, in BERTopic._extract_embeddings(self, documents, images, method, verbose)
#    3408     embeddings = self.embedding_model.embed_words(words=documents, verbose=verbose)
#    3409 elif method == "document":
# -> 3410     embeddings = self.embedding_model.embed_documents(documents, verbose=verbose)
#    3411 elif documents[0] is None and images is None:
#    3412     raise ValueError("Make sure to use an embedding model that can either embed documents"
#    3413                      "or images depending on which you want to embed.")
#
# File /opt/conda/lib/python3.10/site-packages/bertopic/backend/_base.py:69, in BaseEmbedder.embed_documents(self, document, verbose)
#      55 def embed_documents(self,
#      56                     document: List[str],
#      57                     verbose: bool = False) -> np.ndarray:
#      58     """ Embed a list of n words into an n-dimensional
#      59     matrix of embeddings
#      60
#    (...)
#      67         that each have an embeddings size of `m`
#      68     """
# ---> 69     return self.embed(document, verbose)
#
# File /opt/conda/lib/python3.10/site-packages/bertopic/backend/_sentencetransformers.py:65, in SentenceTransformerBackend.embed(self, documents, verbose)
#      51 def embed(self,
#      52           documents: List[str],
#      53           verbose: bool = False) -> np.ndarray:
#      54     """ Embed a list of n documents/words into an n-dimensional
#      55     matrix of embeddings
#      56
#    (...)
#      63         that each have an embeddings size of `m`
#      64     """
# ---> 65     embeddings = self.embedding_model.encode(documents, show_progress_bar=verbose)
#      66     return embeddings
#
# File /opt/conda/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:484, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     482 for start_index in trange(0, len(sentences), batch_size, desc="Batches", disable=not show_progress_bar):
#     483     sentences_batch = sentences_sorted[start_index : start_index + batch_size]
# --> 484     features = self.tokenize(sentences_batch)
#     485     if self.device.type == "hpu":
#     486         if "input_ids" in features:
#
# File /opt/conda/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:916, in SentenceTransformer.tokenize(self, texts)
#     905 def tokenize(self, texts: Union[List[str], List[Dict], List[Tuple[str, str]]]) -> Dict[str, Tensor]:
#     906     """
#     907     Tokenizes the texts.
#     908
#    (...)
#     914             "attention_mask", and "token_type_ids".
#     915     """
# --> 916     return self._first_module().tokenize(texts)
#
# File /opt/conda/lib/python3.10/site-packages/sentence_transformers/models/Transformer.py:163, in Transformer.tokenize(self, texts, padding)
#     159 if self.do_lower_case:
#     160     to_tokenize = [[s.lower() for s in col] for col in to_tokenize]
#     162 output.update(
# --> 163     self.tokenizer(
#     164         *to_tokenize,
#     165         padding=padding,
#     166         truncation="longest_first",
#     167         return_tensors="pt",
#     168         max_length=self.max_seq_length,
#     169     )
#     170 )
#     171 return output
#
# File /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2872, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2870     if not self._in_target_context_manager:
#    2871         self._switch_to_input_mode()
# -> 2872     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2873 if text_target is not None:
#    2874     self._switch_to_target_mode()
#
# File /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:2958, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2953         raise ValueError(
#    2954             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2955             f" {len(text_pair)}."
#    2956         )
#    2957     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2958     return self.batch_encode_plus(
#    2959         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2960         add_special_tokens=add_special_tokens,
#    2961         padding=padding,
#    2962         truncation=truncation,
#    2963         max_length=max_length,
#    2964         stride=stride,
#    2965         is_split_into_words=is_split_into_words,
#    2966         pad_to_multiple_of=pad_to_multiple_of,
#    2967         return_tensors=return_tensors,
#    2968         return_token_type_ids=return_token_type_ids,
#    2969         return_attention_mask=return_attention_mask,
#    2970         return_overflowing_tokens=return_overflowing_tokens,
#    2971         return_special_tokens_mask=return_special_tokens_mask,
#    2972         return_offsets_mapping=return_offsets_mapping,
#    2973         return_length=return_length,
#    2974         verbose=verbose,
#    2975         **kwargs,
#    2976     )
#    2977 else:
#    2978     return self.encode_plus(
#    2979         text=text,
#    2980         text_pair=text_pair,
#    (...)
#    2996         **kwargs,
#    2997     )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:3149, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3139 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3140 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3141     padding=padding,
#    3142     truncation=truncation,
#    (...)
#    3146     **kwargs,
#    3147 )
# -> 3149 return self._batch_encode_plus(
#    3150     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3151     add_special_tokens=add_special_tokens,
#    3152     padding_strategy=padding_strategy,
#    3153     truncation_strategy=truncation_strategy,
#    3154     max_length=max_length,
#    3155     stride=stride,
#    3156     is_split_into_words=is_split_into_words,
#    3157     pad_to_multiple_of=pad_to_multiple_of,
#    3158     return_tensors=return_tensors,
#    3159     return_token_type_ids=return_token_type_ids,
#    3160     return_attention_mask=return_attention_mask,
#    3161     return_overflowing_tokens=return_overflowing_tokens,
#    3162     return_special_tokens_mask=return_special_tokens_mask,
#    3163     return_offsets_mapping=return_offsets_mapping,
#    3164     return_length=return_length,
#    3165     verbose=verbose,
#    3166     **kwargs,
#    3167 )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/tokenization_utils_fast.py:504, in PreTrainedTokenizerFast._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose)
#     495 # Set the truncation and padding strategy and restore the initial configuration
#     496 self.set_truncation_and_padding(
#     497     padding_strategy=padding_strategy,
#     498     truncation_strategy=truncation_strategy,
#    (...)
#     501     pad_to_multiple_of=pad_to_multiple_of,
#     502 )
# --> 504 encodings = self._tokenizer.encode_batch(
#     505     batch_text_or_text_pairs,
#     506     add_special_tokens=add_special_tokens,
#     507     is_pretokenized=is_split_into_words,
#     508 )
#     510 # Convert encoding to dict
#     511 # `Tokens` has type: Tuple[
#     512 #                       List[Dict[str, List[List[int]]]] or List[Dict[str, 2D-Tensor]],
#     513 #                       List[EncodingFast]
#     514 #                    ]
#     515 # with nested dimensions corresponding to batch, overflows, sequence length
#     516 tokens_and_encodings = [
#     517     self._convert_encoding(
#     518         encoding=encoding,
#    (...)
#     527     for encoding in encodings
#     528 ]
#
# KeyboardInterrupt:

# %%
topic_distr, _ = topic_model.approximate_distribution(docs)

# %%
topic_distr, topic_token_distr = topic_model.approximate_distributions(docs, calculate_tokens= True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 topic_distr, topic_token_distr = topic_model.approximate_distributions(docs, calculate_tokens= True)
#
# AttributeError: 'BERTopic' object has no attribute 'approximate_distributions'

# %%
find_topics(search_term=None, image=None, top_n=5)
