# %% [markdown]
# <a href="https://colab.research.google.com/github/ElisaMisu/KinkyBERT/blob/main/Schippersdatavisualisations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import scipy.cluster.hierarchy as sch
import matplotlib.pyplot as plt

# Define the data as a dictionary
data = {
    "Items": ["Being tied", "Surrendering your will", "Having breathing restricted", "Being made to gag",
              "Being tortured", "Being spanked", "Wax dripped on you", "Being humiliated", "Filming sex",
              "Age 8-12", "Age 13-16", "Under 8", "Family member", "Touching someone in public", "Animal",
              "Forcing someone", "Exposing genitals", "Spying on someone", "Asleep, drugged, unconscious",
              "Corpse", "Public place", "Someone at your mercy", "Tying someone", "Spanking someone",
              "Restricting someone's breathing", "Blindfolding someone", "Humiliating someone",
              "Making someone gag", "Dripping wax on someone", "Virgin", "Orgy", "Defecating on someone",
              "Torturing someone", "Urinating on someone", "Being urinated on", "Being defecated on", "Enema",
              "Blood", "Committed relationship", "Someone dressed plush animal", "Being dressed as plush animal",
              "Dwarfism", "Blow-up doll", "Someone overweight", "Dressing up as opposite sex", "Feet",
              "Rubber, latex, leather", "Prostitute", "Someone as old as parent", "Watch partner w/someone else"],
    "Submission/Masochism": [0.77, 0.77, 0.74, 0.73, 0.66, 0.65, 0.64, 0.64, 0.30, -0.01, -0.11, -0.01, -0.02, 0.00, 0.07, 0.02, 0.13, -0.13, -0.01, 0.03, 0.18, -0.12, 0.06, 0.00, 0.23, 0.11, 0.04, 0.11, 0.16, -0.15, 0.26, -0.01, 0.14, -0.04, 0.22, 0.07, 0.20, 0.28, 0.11, -0.12, -0.04, -0.07, 0.00, 0.06, 0.05, -0.01, 0.23, 0.09, 0.16, 0.18],
    "Forbidden": [-0.02, 0.03, 0.03, -0.02, -0.01, -0.03, -0.08, 0.02, 0.16, 0.71, 0.70, 0.66, 0.64, 0.59, 0.59, 0.54, 0.51, 0.49, 0.48, 0.37, 0.26, 0.02, -0.01, -0.06, 0.01, -0.02, 0.00, 0.03, -0.12, 0.22, 0.11, 0.20, 0.10, 0.04, 0.06, 0.21, -0.03, 0.01, -0.03, 0.04, 0.06, 0.05, 0.16, 0.01, -0.06, -0.04, -0.06, 0.11, 0.12, 0.15],
    "Dominance/Sadism": [-0.04, -0.07, 0.10, -0.01, 0.01, 0.06, 0.03, 0.04, 0.23, -0.11, 0.05, -0.14, -0.02, 0.03, -0.22, 0.32, -0.04, 0.20, 0.24, -0.02, 0.24, 0.76, 0.75, 0.70, 0.63, 0.63, 0.59, 0.58, 0.52, 0.32, 0.28, 0.03, 0.46, 0.25, 0.01, -0.08, 0.05, 0.07, 0.09, -0.00, -0.09, 0.06, 0.03, -0.03, 0.05, 0.13, 0.21, 0.21, 0.01, 0.13],
    "Mysophilia": [-0.17, -0.14, -0.00, 0.11, 0.34, -0.05, -0.00, 0.24, -0.14, 0.06, 0.05, 0.06, 0.04, -0.07, 0.01, 0.18, -0.17, -0.02, 0.17, 0.19, -0.26, -0.03, -0.17, -0.00, 0.10, -0.25, 0.29, 0.23, 0.05, -0.02, -0.08, 0.48, 0.47, 0.47, 0.46, 0.45, 0.38, 0.34, -0.21, 0.05, 0.01, -0.01, -0.02, -0.01, 0.05, 0.15, -0.05, -0.04, -0.05, 0.07],
    "Fetishism": [0.05, 0.05, -0.13, -0.04, -0.06, -0.00, 0.18, 0.02, 0.16, 0.05, -0.00, 0.04, 0.14, 0.01, 0.22, -0.21, 0.05, -0.02, -0.03, 0.01, 0.04, 0.12, 0.07, 0.11, -0.07, 0.05, 0.08, -0.01, 0.24, 0.07, 0.23, 0.11, -0.08, 0.30, 0.31, 0.14, 0.16, 0.20, 0.07, 0.72, 0.68, 0.56, 0.54, 0.53, 0.53, 0.41, 0.41, 0.38, 0.25, 0.24]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Drop the 'Items' column for clustering
df_clustering = df.drop("Items", axis=1)

# Perform hierarchical clustering using Euclidean distance
linked = sch.linkage(df_clustering, method='ward', metric='euclidean')

# Plot the dendrogram
plt.figure(figsize=(10, 7))
dendrogram = sch.dendrogram(linked, labels=df['Items'].values, orientation='right')
plt.title("Dendrogram of Schippers et al. Paraphilia items")
plt.xlabel("Euclidean distances")
plt.ylabel("Items")
plt.show()

# %%
# !pip install plotly

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Define the data as a dictionary
data = {
    "Items": ["Being tied", "Surrendering your will", "Having breathing restricted", "Being made to gag",
              "Being tortured", "Being spanked", "Wax dripped on you", "Being humiliated", "Filming sex",
              "Age 8-12", "Age 13-16", "Under 8", "Family member", "Touching someone in public", "Animal",
              "Forcing someone", "Exposing genitals", "Spying on someone", "Asleep, drugged, unconscious",
              "Corpse", "Public place", "Someone at your mercy", "Tying someone", "Spanking someone",
              "Restricting someone's breathing", "Blindfolding someone", "Humiliating someone",
              "Making someone gag", "Dripping wax on someone", "Virgin", "Orgy", "Defecating on someone",
              "Torturing someone", "Urinating on someone", "Being urinated on", "Being defecated on", "Enema",
              "Blood", "Committed relationship", "Someone dressed plush animal", "Being dressed as plush animal",
              "Dwarfism", "Blow-up doll", "Someone overweight", "Dressing up as opposite sex", "Feet",
              "Rubber, latex, leather", "Prostitute", "Someone as old as parent", "Watch partner w/someone else"],
    "Submission/Masochism": [0.77, 0.77, 0.74, 0.73, 0.66, 0.65, 0.64, 0.64, 0.30, -0.01, -0.11, -0.01, -0.02, 0.00, 0.07, 0.02, 0.13, -0.13, -0.01, 0.03, 0.18, -0.12, 0.06, 0.00, 0.23, 0.11, 0.04, 0.11, 0.16, -0.15, 0.26, -0.01, 0.14, -0.04, 0.22, 0.07, 0.20, 0.28, 0.11, -0.12, -0.04, -0.07, 0.00, 0.06, 0.05, -0.01, 0.23, 0.09, 0.16, 0.18],
    "Forbidden": [-0.02, 0.03, 0.03, -0.02, -0.01, -0.03, -0.08, 0.02, 0.16, 0.71, 0.70, 0.66, 0.64, 0.59, 0.59, 0.54, 0.51, 0.49, 0.48, 0.37, 0.26, 0.02, -0.01, -0.06, 0.01, -0.02, 0.00, 0.03, -0.12, 0.22, 0.11, 0.20, 0.10, 0.04, 0.06, 0.21, -0.03, 0.01, -0.03, 0.04, 0.06, 0.05, 0.16, 0.01, -0.06, -0.04, -0.06, 0.11, 0.12, 0.15],
    "Dominance/Sadism": [-0.04, -0.07, 0.10, -0.01, 0.01, 0.06, 0.03, 0.04, 0.23, -0.11, 0.05, -0.14, -0.02, 0.03, -0.22, 0.32, -0.04, 0.20, 0.24, -0.02, 0.24, 0.76, 0.75, 0.70, 0.63, 0.63, 0.59, 0.58, 0.52, 0.32, 0.28, 0.03, 0.46, 0.25, 0.01, -0.08, 0.05, 0.07, 0.09, -0.00, -0.09, 0.06, 0.03, -0.03, 0.05, 0.13, 0.21, 0.21, 0.01, 0.13],
    "Mysophilia": [-0.17, -0.14, -0.00, 0.11, 0.34, -0.05, -0.00, 0.24, -0.14, 0.06, 0.05, 0.06, 0.04, -0.07, 0.01, 0.18, -0.17, -0.02, 0.17, 0.19, -0.26, -0.03, -0.17, -0.00, 0.10, -0.25, 0.29, 0.23, 0.05, -0.02, -0.08, 0.48, 0.47, 0.47, 0.46, 0.45, 0.38, 0.34, -0.21, 0.05, 0.01, -0.01, -0.02, -0.01, 0.05, 0.15, -0.05, -0.04, -0.05, 0.07],
    "Fetishism": [0.05, 0.05, -0.13, -0.04, -0.06, -0.00, 0.18, 0.02, 0.16, 0.05, -0.00, 0.04, 0.14, 0.01, 0.22, -0.21, 0.05, -0.02, -0.03, 0.01, 0.04, 0.12, 0.07, 0.11, -0.07, 0.05, 0.08, -0.01, 0.24, 0.07, 0.23, 0.11, -0.08, 0.30, 0.31, 0.14, 0.16, 0.20, 0.07, 0.72, 0.68, 0.56, 0.54, 0.53, 0.53, 0.41, 0.41, 0.38, 0.25, 0.24]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Function to create a radar chart for each item
def create_radar_chart(df, item):
    categories = df.columns[1:]
    values = df[df['Items'] == item].values.flatten().tolist()[1:]
    values += values[:1]  # Ensure the plot is a closed loop

    fig = go.Figure(
        data=[
            go.Scatterpolar(
                r=values,
                theta=categories,
                fill='toself',
                name=item
            )
        ],
        layout=go.Layout(
            title=go.layout.Title(text=f"Radar Chart for {item}"),
            polar={'radialaxis': {'visible': True}},
            showlegend=True
        )
    )
    fig.show()

# Example: Create a radar chart for "Being tied"
create_radar_chart(df, "Being tied")

# Optionally, create radar charts for all items
for item in df['Items']:
    create_radar_chart(df, item)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch

# Define the data as a dictionary
data = {
    "Items": ["Being tied", "Surrendering your will", "Having breathing restricted", "Being made to gag",
              "Being tortured", "Being spanked", "Wax dripped on you", "Being humiliated", "Filming sex",
              "Age 8-12", "Age 13-16", "Under 8", "Family member", "Touching someone in public", "Animal",
              "Forcing someone", "Exposing genitals", "Spying on someone", "Asleep, drugged, unconscious",
              "Corpse", "Public place", "Someone at your mercy", "Tying someone", "Spanking someone",
              "Restricting someone's breathing", "Blindfolding someone", "Humiliating someone",
              "Making someone gag", "Dripping wax on someone", "Virgin", "Orgy", "Defecating on someone",
              "Torturing someone", "Urinating on someone", "Being urinated on", "Being defecated on", "Enema",
              "Blood", "Committed relationship", "Someone dressed plush animal", "Being dressed as plush animal",
              "Dwarfism", "Blow-up doll", "Someone overweight", "Dressing up as opposite sex", "Feet",
              "Rubber, latex, leather", "Prostitute", "Someone as old as parent", "Watch partner w/someone else"],
    "Submission/Masochism": [0.77, 0.77, 0.74, 0.73, 0.66, 0.65, 0.64, 0.64, 0.30, -0.01, -0.11, -0.01, -0.02, 0.00, 0.07, 0.02, 0.13, -0.13, -0.01, 0.03, 0.18, -0.12, 0.06, 0.00, 0.23, 0.11, 0.04, 0.11, 0.16, -0.15, 0.26, -0.01, 0.14, -0.04, 0.22, 0.07, 0.20, 0.28, 0.11, -0.12, -0.04, -0.07, 0.00, 0.06, 0.05, -0.01, 0.23, 0.09, 0.16, 0.18],
    "Forbidden": [-0.02, 0.03, 0.03, -0.02, -0.01, -0.03, -0.08, 0.02, 0.16, 0.71, 0.70, 0.66, 0.64, 0.59, 0.59, 0.54, 0.51, 0.49, 0.48, 0.37, 0.26, 0.02, -0.01, -0.06, 0.01, -0.02, 0.00, 0.03, -0.12, 0.22, 0.11, 0.20, 0.10, 0.04, 0.06, 0.21, -0.03, 0.01, -0.03, 0.04, 0.06, 0.05, 0.16, 0.01, -0.06, -0.04, -0.06, 0.11, 0.12, 0.15],
    "Dominance/Sadism": [-0.04, -0.07, 0.10, -0.01, 0.01, 0.06, 0.03, 0.04, 0.23, -0.11, 0.05, -0.14, -0.02, 0.03, -0.22, 0.32, -0.04, 0.20, 0.24, -0.02, 0.24, 0.76, 0.75, 0.70, 0.63, 0.63, 0.59, 0.58, 0.52, 0.32, 0.28, 0.03, 0.46, 0.25, 0.01, -0.08, 0.05, 0.07, 0.09, -0.00, -0.09, 0.06, 0.03, -0.03, 0.05, 0.13, 0.21, 0.21, 0.01, 0.13],
    "Mysophilia": [-0.17, -0.14, -0.00, 0.11, 0.34, -0.05, -0.00, 0.24, -0.14, 0.06, 0.05, 0.06, 0.04, -0.07, 0.01, 0.18, -0.17, -0.02, 0.17, 0.19, -0.26, -0.03, -0.17, -0.00, 0.10, -0.25, 0.29, 0.23, 0.05, -0.02, -0.08, 0.48, 0.47, 0.47, 0.46, 0.45, 0.38, 0.34, -0.21, 0.05, 0.01, -0.01, -0.02, -0.01, 0.05, 0.15, -0.05, -0.04, -0.05, 0.07],
    "Fetishism": [0.05, 0.05, -0.13, -0.04, -0.06, -0.00, 0.18, 0.02, 0.16, 0.05, -0.00, 0.04, 0.14, 0.01, 0.22, -0.21, 0.05, -0.02, -0.03, 0.01, 0.04, 0.12, 0.07, 0.11, -0.07, 0.05, 0.08, -0.01, 0.24, 0.07, 0.23, 0.11, -0.08, 0.30, 0.31, 0.14, 0.16, 0.20, 0.07, 0.72, 0.68, 0.56, 0.54, 0.53, 0.53, 0.41, 0.41, 0.38, 0.25, 0.24]
}

# Create a DataFrame
df = pd.DataFrame(data)
df.set_index("Items", inplace=True)

# Perform hierarchical clustering using Euclidean distance and ward linkage
linkage = sch.linkage(df, method='ward', metric='euclidean')

# Create a dendrogram with heatmap
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10), gridspec_kw={"width_ratios": [1, 4]})

# Dendrogram
dendro = sch.dendrogram(linkage, orientation='left', ax=ax1, labels=df.index)
ax1.set_yticklabels(dendro['ivl'], fontsize=10)
ax1.set_xticks([])
ax1.set_frame_on(False)

# Reindex the DataFrame according to the clustering
df_reindexed = df.loc[dendro['ivl'], :]

# Heatmap
sns.heatmap(df_reindexed, cmap="coolwarm", ax=ax2, cbar_kws={"shrink": .8}, annot=True)
ax2.set_yticks([])

plt.tight_layout()
plt.title("Dendrogram with Heatmap of Schippers et al., 2021 EFA")
plt.show()
